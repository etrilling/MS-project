# %%
# %load_ext autoreload
# %autoreload 2

from src.dynamical_systems import *
from src.SINDyModel import *
from src.derivatives import *
from src.helpers import *

import matplotlib.pyplot as plt
from tqdm import tqdm
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def pick_threshold_value(rhs, true_coefficients, x0, dt, t_span, rce_threshold=0.002):
    t_eval = np.arange(t_span[0], t_span[1] + dt, dt)

    # generate ground truth data
    x_train = generate_training_data(rhs, x0, t_eval)

    # generate training data with a very small amount of noise
    x_train_noisy = add_noise_to_data(x_train, noise_level=0.0001)
    x_dot_approx = dxdt_finite_difference(x_train_noisy, t_eval)
    # x_train_noisy = x_train
    # x_dot_approx = rhs(0, x_train)

    n = 100
    thresholds = np.logspace(-5, 0, n)
    results = np.zeros(len(thresholds))

    for i in range(n):
        threshold = thresholds[i]

        model = SINDyModel(n_state_vars=2, threshold=threshold, poly_order=5)
        model.fit(x_train_noisy, x_dot_approx)

        rce = relative_coefficient_error(true_coefficients, model.Xi)

        if rce < rce_threshold:
            results[i] = 1

            print(f"threshold: {threshold:.5f},    did work, relative_coefficient_error: {rce:.5f}")
        else:
            print(f"threshold: {threshold:.5f}, didn't work, relative_coefficient_error: {rce:.5f}")
    
    # check if any viable thresholds were found
    if np.sum(results) == 0:
        print("no viable thresholds found")
        return None

    # get the average viable threshold
    # mean_index = np.rint(np.mean(np.nonzero(results))).astype(int)
    # mean_threshold = thresholds[mean_index]
    mean_threshold = (thresholds[np.max(np.nonzero(results))] + thresholds[np.min(np.nonzero(results))]) / 2

    return mean_threshold


lotka_volterra_rhs = generate_lotka_volterra_rhs(1, 0.1, 1.5, 0.75)
model = SINDyModel(n_state_vars=2, threshold=0.05, poly_order=5)
true_coefficents = generate_lotka_volterra_true_coefficients(1, 0.1, 1.5, 0.75)


x0 = (5, 20)
dt = 0.01
t_span = (0, 50)


pick_threshold_value(lotka_volterra_rhs, true_coefficents, x0, dt, t_span, rce_threshold=0.002)
# Out:
# threshold: 0.00001, didn't work, relative_coefficient_error: 0.24606
# threshold: 0.00001, didn't work, relative_coefficient_error: 0.24606
# threshold: 0.00001, didn't work, relative_coefficient_error: 0.59896
# threshold: 0.00001, didn't work, relative_coefficient_error: 0.59896
# threshold: 0.00002, didn't work, relative_coefficient_error: 0.59896
# threshold: 0.00002, didn't work, relative_coefficient_error: 0.59908
# threshold: 0.00002, didn't work, relative_coefficient_error: 0.59908
# threshold: 0.00002, didn't work, relative_coefficient_error: 0.59908
# threshold: 0.00003, didn't work, relative_coefficient_error: 0.61079
# threshold: 0.00003, didn't work, relative_coefficient_error: 0.61079
# threshold: 0.00003, didn't work, relative_coefficient_error: 0.55515
# threshold: 0.00004, didn't work, relative_coefficient_error: 0.20873
# threshold: 0.00004, didn't work, relative_coefficient_error: 0.20873
# threshold: 0.00005, didn't work, relative_coefficient_error: 0.20873
# threshold: 0.00005, didn't work, relative_coefficient_error: 0.01578
# threshold: 0.00006, didn't work, relative_coefficient_error: 0.03503
# threshold: 0.00006, didn't work, relative_coefficient_error: 0.03537
# threshold: 0.00007, didn't work, relative_coefficient_error: 0.03537
# threshold: 0.00008, didn't work, relative_coefficient_error: 0.03537
# threshold: 0.00009, didn't work, relative_coefficient_error: 0.00642
# threshold: 0.00010, didn't work, relative_coefficient_error: 0.00642
# threshold: 0.00011, didn't work, relative_coefficient_error: 0.00642
# threshold: 0.00013,    did work, relative_coefficient_error: 0.00030
# threshold: 0.00015,    did work, relative_coefficient_error: 0.00010
# threshold: 0.00016,    did work, relative_coefficient_error: 0.00010
# threshold: 0.00018, didn't work, relative_coefficient_error: 0.00642
# threshold: 0.00021, didn't work, relative_coefficient_error: 0.00642
# threshold: 0.00023, didn't work, relative_coefficient_error: 0.00642
# threshold: 0.00026, didn't work, relative_coefficient_error: 0.00642
# threshold: 0.00029, didn't work, relative_coefficient_error: 0.00642
# threshold: 0.00033, didn't work, relative_coefficient_error: 0.00642
# threshold: 0.00037, didn't work, relative_coefficient_error: 0.00642
# threshold: 0.00041, didn't work, relative_coefficient_error: 0.00642
# threshold: 0.00046,    did work, relative_coefficient_error: 0.00154
# threshold: 0.00052,    did work, relative_coefficient_error: 0.00154
# threshold: 0.00059,    did work, relative_coefficient_error: 0.00010
# threshold: 0.00066,    did work, relative_coefficient_error: 0.00010
# threshold: 0.00074,    did work, relative_coefficient_error: 0.00010
# threshold: 0.00083,    did work, relative_coefficient_error: 0.00010
# threshold: 0.00093,    did work, relative_coefficient_error: 0.00010
# threshold: 0.00105,    did work, relative_coefficient_error: 0.00010
# threshold: 0.00118,    did work, relative_coefficient_error: 0.00010
# threshold: 0.00132,    did work, relative_coefficient_error: 0.00010
# threshold: 0.00148,    did work, relative_coefficient_error: 0.00010
# threshold: 0.00167,    did work, relative_coefficient_error: 0.00010
# threshold: 0.00187,    did work, relative_coefficient_error: 0.00010
# threshold: 0.00210,    did work, relative_coefficient_error: 0.00010
# threshold: 0.00236,    did work, relative_coefficient_error: 0.00010
# threshold: 0.00266,    did work, relative_coefficient_error: 0.00010
# threshold: 0.00298,    did work, relative_coefficient_error: 0.00010
# threshold: 0.00335,    did work, relative_coefficient_error: 0.00010
# threshold: 0.00376,    did work, relative_coefficient_error: 0.00010
# threshold: 0.00423,    did work, relative_coefficient_error: 0.00010
# threshold: 0.00475,    did work, relative_coefficient_error: 0.00010
# threshold: 0.00534,    did work, relative_coefficient_error: 0.00010
# threshold: 0.00599,    did work, relative_coefficient_error: 0.00010
# threshold: 0.00673,    did work, relative_coefficient_error: 0.00010
# threshold: 0.00756,    did work, relative_coefficient_error: 0.00010
# threshold: 0.00850,    did work, relative_coefficient_error: 0.00010
# threshold: 0.00955,    did work, relative_coefficient_error: 0.00010
# threshold: 0.01072,    did work, relative_coefficient_error: 0.00010
# threshold: 0.01205,    did work, relative_coefficient_error: 0.00010
# threshold: 0.01353,    did work, relative_coefficient_error: 0.00010
# threshold: 0.01520,    did work, relative_coefficient_error: 0.00010
# threshold: 0.01707,    did work, relative_coefficient_error: 0.00010
# threshold: 0.01918,    did work, relative_coefficient_error: 0.00010
# threshold: 0.02154,    did work, relative_coefficient_error: 0.00010
# threshold: 0.02420,    did work, relative_coefficient_error: 0.00010
# threshold: 0.02719,    did work, relative_coefficient_error: 0.00010
# threshold: 0.03054,    did work, relative_coefficient_error: 0.00010
# threshold: 0.03430,    did work, relative_coefficient_error: 0.00010
# threshold: 0.03854,    did work, relative_coefficient_error: 0.00010
# threshold: 0.04329,    did work, relative_coefficient_error: 0.00010
# threshold: 0.04863, didn't work, relative_coefficient_error: 0.51403
# threshold: 0.05462, didn't work, relative_coefficient_error: 0.51403
# threshold: 0.06136, didn't work, relative_coefficient_error: 0.51403
# threshold: 0.06893, didn't work, relative_coefficient_error: 0.51403
# threshold: 0.07743, didn't work, relative_coefficient_error: 0.51403
# threshold: 0.08697, didn't work, relative_coefficient_error: 0.51403
# threshold: 0.09770, didn't work, relative_coefficient_error: 0.51403
# threshold: 0.10975, didn't work, relative_coefficient_error: 0.51403
# threshold: 0.12328, didn't work, relative_coefficient_error: 0.51403
# threshold: 0.13849, didn't work, relative_coefficient_error: 0.51403
# threshold: 0.15557, didn't work, relative_coefficient_error: 0.51403
# threshold: 0.17475, didn't work, relative_coefficient_error: 0.51403
# threshold: 0.19630, didn't work, relative_coefficient_error: 0.51403
# threshold: 0.22051, didn't work, relative_coefficient_error: 0.51403
# threshold: 0.24771, didn't work, relative_coefficient_error: 0.51403
# threshold: 0.27826, didn't work, relative_coefficient_error: 0.51403
# threshold: 0.31257, didn't work, relative_coefficient_error: 0.51403
# threshold: 0.35112, didn't work, relative_coefficient_error: 0.51403
# threshold: 0.39442, didn't work, relative_coefficient_error: 0.51403
# threshold: 0.44306, didn't work, relative_coefficient_error: 0.51403
# threshold: 0.49770, didn't work, relative_coefficient_error: 0.51403
# threshold: 0.55908, didn't work, relative_coefficient_error: 0.51403
# threshold: 0.62803, didn't work, relative_coefficient_error: 0.51403
# threshold: 0.70548, didn't work, relative_coefficient_error: 0.51403
# threshold: 0.79248, didn't work, relative_coefficient_error: 1.00000
# threshold: 0.89022, didn't work, relative_coefficient_error: 1.00000
# threshold: 1.00000, didn't work, relative_coefficient_error: 1.00000
# 0.02170838388866603

# %%
lotka_volterra_rhs = generate_lotka_volterra_rhs(1, 0.1, 1.5, 0.75)


x0 = (10, 20)

dt = 0.01
t_span = (0, 50)
t_eval = np.arange(t_span[0], t_span[1] + dt, dt)

x_train = generate_training_data(lotka_volterra_rhs, x0, t_eval)

plt.plot(t_eval, x_train.T)
plt.show()

# %%
x_train_noisy = add_noise_to_data(x_train, 0.01)

plt.plot(t_eval, x_train.T)
plt.plot(t_eval, x_train_noisy.T, '--')
plt.show()

# %%
# generate the true derivative
x_dot_true = lotka_volterra_rhs(t_eval, x_train)

x_dot_approx = dxdt_finite_difference(x_train_noisy, t_eval)

plt.plot(t_eval, x_dot_true.T)
plt.plot(t_eval, x_dot_approx.T, '--')
plt.show()
