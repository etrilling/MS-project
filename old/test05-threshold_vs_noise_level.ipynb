# %%
# %load_ext autoreload
# %autoreload 2

from src.dynamical_systems import *
from src.SINDyModel import *
from src.derivatives import *
from src.helpers import *
from src.experiments import *

import matplotlib.pyplot as plt
from tqdm import tqdm

# %% [markdown]
# # Lotka-Volterra

# %%
lotka_volterra_rhs = generate_lotka_volterra_rhs(*default_params['lotka_volterra'])
true_coeffs = generate_lotka_volterra_true_coefficients(*default_params['lotka_volterra'])
x0 = default_x0['lotka_volterra']


noise_levels = np.logspace(-3, 0, 10).tolist()
thresholds = np.logspace(-3, -0.5, 11).tolist()

t_span = (0, 50)

experiment_config = {
    # define fixed parameters
    'rhs': lotka_volterra_rhs,
    'derivative_approximation': dxdt_finite_difference,
    't_eval_test': np.arange(t_span[0], t_span[1] + 0.01, 0.01),
    'np_seed': 0,
    'true_coeffs': true_coeffs,
    # define parameters that can be lists
    'x0': x0, 'noise_level': noise_levels,
    't_eval_train': None, 'dt_train': 0.01, 't_span_train': t_span,
    'train_interpolation_dt': None,
    'threshold': thresholds, 'poly_order': 5, 'n_frequencies': 0
}

results = run_experiment(experiment_config)
# Out:
# rows are noise_level. there are 10 rows.
# columns are threshold. there are 11 columns.
# step 1 of 10
# 100%|██████████| 11/11 [00:03<00:00,  2.92it/s]
# step 2 of 10
# 100%|██████████| 11/11 [00:04<00:00,  2.47it/s]
# step 3 of 10
# 100%|██████████| 11/11 [00:05<00:00,  2.08it/s]
# step 4 of 10
# 100%|██████████| 11/11 [00:05<00:00,  2.18it/s]
# step 5 of 10
# 100%|██████████| 11/11 [00:04<00:00,  2.38it/s]
# step 6 of 10
#  27%|██▋       | 3/11 [00:01<00:03,  2.06it/s]c:\Elliot\docs\education\college\2024-2025\MS project\MS-project\src\SINDyModel.py:9: RuntimeWarning: overflow encountered in power
#   return lambda x: np.prod(np.power(x, power_tuple), axis=1)
# c:\Elliot\docs\education\college\2024-2025\MS project\MS-project\src\SINDyModel.py:131: RuntimeWarning: invalid value encountered in matmul
#   x_dot = Theta @ self.Xi
# c:\Users\Elliot\anaconda3\envs\ds312\Lib\site-packages\scipy\integrate\_ivp\lsoda.py:161: UserWarning: lsoda: Excess accuracy requested (tolerances too small).
#   solver._y, solver.t = integrator.run(
# 100%|██████████| 11/11 [00:07<00:00,  1.50it/s]
# step 7 of 10
# 100%|██████████| 11/11 [00:05<00:00,  2.06it/s]
# step 8 of 10
# 100%|██████████| 11/11 [00:04<00:00,  2.56it/s]
# step 9 of 10
# 100%|██████████| 11/11 [00:06<00:00,  1.62it/s]
# step 10 of 10
#   9%|▉         | 1/11 [00:02<00:29,  2.96s/it]c:\Users\Elliot\anaconda3\envs\ds312\Lib\site-packages\numpy\core\fromnumeric.py:88: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# 100%|██████████| 11/11 [00:16<00:00,  1.46s/it]

# %%
plot_heatmaps(experiment_config, results)
# Out:
# rows are noise_level. there are 10 rows.
# columns are threshold. there are 11 columns.

# %%
# display_single_result(experiment_config, results, 3, 2, keys_to_display=['x_test', 'x_pred', 'x_train_noisy'])

# %%
list_of_results = run_test_suite(experiment_config)
# Out:
# rows are noise_level. there are 10 rows.
# columns are threshold. there are 11 columns.
# step 1 of 10
# 100%|██████████| 11/11 [00:03<00:00,  3.10it/s]
# step 2 of 10
# 100%|██████████| 11/11 [00:04<00:00,  2.63it/s]
# step 3 of 10
# 100%|██████████| 11/11 [00:05<00:00,  2.03it/s]
# step 4 of 10
# 100%|██████████| 11/11 [00:04<00:00,  2.20it/s]
# step 5 of 10
# 100%|██████████| 11/11 [00:04<00:00,  2.32it/s]
# step 6 of 10
#  27%|██▋       | 3/11 [00:01<00:04,  1.95it/s]c:\Elliot\docs\education\college\2024-2025\MS project\MS-project\src\SINDyModel.py:9: RuntimeWarning: overflow encountered in power
#   return lambda x: np.prod(np.power(x, power_tuple), axis=1)
# c:\Elliot\docs\education\college\2024-2025\MS project\MS-project\src\SINDyModel.py:131: RuntimeWarning: invalid value encountered in matmul
#   x_dot = Theta @ self.Xi
# c:\Users\Elliot\anaconda3\envs\ds312\Lib\site-packages\scipy\integrate\_ivp\lsoda.py:161: UserWarning: lsoda: Excess accuracy requested (tolerances too small).
#   solver._y, solver.t = integrator.run(
# 100%|██████████| 11/11 [00:07<00:00,  1.46it/s]
# step 7 of 10
# 100%|██████████| 11/11 [00:04<00:00,  2.32it/s]
# step 8 of 10
# 100%|██████████| 11/11 [00:03<00:00,  2.76it/s]
# step 9 of 10
# 100%|██████████| 11/11 [00:07<00:00,  1.55it/s]
# step 10 of 10
#   9%|▉         | 1/11 [00:03<00:33,  3.40s/it]c:\Users\Elliot\anaconda3\envs\ds312\Lib\site-packages\numpy\core\fromnumeric.py:88: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# 100%|██████████| 11/11 [00:17<00:00,  1.59s/it]
# ******************************Lotka-Volterra******************************
# rows are noise_level. there are 10 rows.
# columns are threshold. there are 11 columns.
# rows are noise_level. there are 10 rows.
# columns are threshold. there are 11 columns.
# step 1 of 10
# 100%|██████████| 11/11 [00:14<00:00,  1.31s/it]
# step 2 of 10
# 100%|██████████| 11/11 [00:13<00:00,  1.22s/it]
# step 3 of 10
# 100%|██████████| 11/11 [00:13<00:00,  1.19s/it]
# step 4 of 10
# 100%|██████████| 11/11 [00:13<00:00,  1.23s/it]
# step 5 of 10
# 100%|██████████| 11/11 [00:13<00:00,  1.24s/it]
# step 6 of 10
# 100%|██████████| 11/11 [00:13<00:00,  1.21s/it]
# step 7 of 10
# 100%|██████████| 11/11 [00:12<00:00,  1.17s/it]
# step 8 of 10
# 100%|██████████| 11/11 [00:11<00:00,  1.05s/it]
# step 9 of 10
# 100%|██████████| 11/11 [00:06<00:00,  1.73it/s]
# step 10 of 10
#  55%|█████▍    | 6/11 [00:02<00:02,  2.33it/s]c:\Elliot\docs\education\college\2024-2025\MS project\MS-project\src\SINDyModel.py:9: RuntimeWarning: overflow encountered in power
#   return lambda x: np.prod(np.power(x, power_tuple), axis=1)
# c:\Elliot\docs\education\college\2024-2025\MS project\MS-project\src\SINDyModel.py:131: RuntimeWarning: invalid value encountered in matmul
#   x_dot = Theta @ self.Xi
# c:\Users\Elliot\anaconda3\envs\ds312\Lib\site-packages\scipy\integrate\_ivp\lsoda.py:161: UserWarning: lsoda: Excess accuracy requested (tolerances too small).
#   solver._y, solver.t = integrator.run(
#  73%|███████▎  | 8/11 [00:09<00:06,  2.02s/it]c:\Users\Elliot\anaconda3\envs\ds312\Lib\site-packages\numpy\core\fromnumeric.py:88: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# 100%|██████████| 11/11 [00:13<00:00,  1.21s/it]
# ******************************Van der Pol Oscillator******************************
# rows are noise_level. there are 10 rows.
# columns are threshold. there are 11 columns.
# rows are noise_level. there are 10 rows.
# columns are threshold. there are 11 columns.
# step 1 of 10
# 100%|██████████| 11/11 [00:04<00:00,  2.70it/s]
# step 2 of 10
# 100%|██████████| 11/11 [00:04<00:00,  2.51it/s]
# step 3 of 10
# 100%|██████████| 11/11 [00:03<00:00,  2.78it/s]
# step 4 of 10
# 100%|██████████| 11/11 [00:03<00:00,  2.92it/s]
# step 5 of 10
# 100%|██████████| 11/11 [00:04<00:00,  2.70it/s]
# step 6 of 10
# 100%|██████████| 11/11 [00:03<00:00,  3.03it/s]
# step 7 of 10
# 100%|██████████| 11/11 [00:04<00:00,  2.56it/s]
# step 8 of 10
# 100%|██████████| 11/11 [00:04<00:00,  2.52it/s]
# step 9 of 10
# 100%|██████████| 11/11 [00:02<00:00,  4.01it/s]
# step 10 of 10
# 100%|██████████| 11/11 [00:26<00:00,  2.39s/it]
# ******************************Duffing Oscillator******************************
# rows are noise_level. there are 10 rows.
# columns are threshold. there are 11 columns.
# rows are noise_level. there are 10 rows.
# columns are threshold. there are 11 columns.
# step 1 of 10
# 100%|██████████| 11/11 [00:06<00:00,  1.72it/s]
# step 2 of 10
# 100%|██████████| 11/11 [00:05<00:00,  2.04it/s]
# step 3 of 10
# 100%|██████████| 11/11 [00:06<00:00,  1.79it/s]
# step 4 of 10
# 100%|██████████| 11/11 [00:07<00:00,  1.46it/s]
# step 5 of 10
# 100%|██████████| 11/11 [00:06<00:00,  1.62it/s]
# step 6 of 10
# 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
/it]
# timeout occurred in solve_ivp_with_timeout
# 100%|██████████| 11/11 [01:06<00:00,  6.06s/it]
# step 7 of 10
#   0%|          | 0/11 [00:00<?, ?it/s]
# timeout occurred in solve_ivp_with_timeout
#   9%|▉         | 1/11 [00:05<00:58,  5.87s/it]
# timeout occurred in solve_ivp_with_timeout
#  18%|█▊        | 2/11 [00:11<00:53,  5.90s/it]
# timeout occurred in solve_ivp_with_timeout
#  27%|██▋       | 3/11 [00:17<00:47,  5.89s/it]
# timeout occurred in solve_ivp_with_timeout
#  36%|███▋      | 4/11 [00:23<00:41,  5.93s/it]
# timeout occurred in solve_ivp_with_timeout
#  45%|████▌     | 5/11 [00:29<00:35,  5.91s/it]
# timeout occurred in solve_ivp_with_timeout
#  55%|█████▍    | 6/11 [00:35<00:29,  5.99s/it]
# timeout occurred in solve_ivp_with_timeout
#  64%|██████▎   | 7/11 [00:41<00:24,  6.08s/it]
# timeout occurred in solve_ivp_with_timeout
#  73%|███████▎  | 8/11 [00:48<00:18,  6.12s/it]
# timeout occurred in solve_ivp_with_timeout
#  82%|████████▏ | 9/11 [00:54<00:12,  6.12s/it]
# timeout occurred in solve_ivp_with_timeout
#  91%|█████████ | 10/11 [01:00<00:06,  6.17s/it]
# timeout occurred in solve_ivp_with_timeout
# 100%|██████████| 11/11 [01:06<00:00,  6.09s/it]
# step 8 of 10
#   0%|          | 0/11 [00:00<?, ?it/s]
# timeout occurred in solve_ivp_with_timeout
#   9%|▉         | 1/11 [00:06<01:04,  6.41s/it]
# timeout occurred in solve_ivp_with_timeout
#  27%|██▋       | 3/11 [00:17<00:46,  5.86s/it]
# timeout occurred in solve_ivp_with_timeout
#  36%|███▋      | 4/11 [00:24<00:41,  5.99s/it]
# timeout occurred in solve_ivp_with_timeout
#  45%|████▌     | 5/11 [00:30<00:36,  6.08s/it]
# timeout occurred in solve_ivp_with_timeout
#  55%|█████▍    | 6/11 [00:36<00:30,  6.08s/it]
# timeout occurred in solve_ivp_with_timeout
#  64%|██████▎   | 7/11 [00:42<00:24,  6.09s/it]
# timeout occurred in solve_ivp_with_timeout
#  73%|███████▎  | 8/11 [00:48<00:18,  6.10s/it]
# timeout occurred in solve_ivp_with_timeout
#  82%|████████▏ | 9/11 [00:54<00:12,  6.10s/it]
# timeout occurred in solve_ivp_with_timeout
# 100%|██████████| 11/11 [01:04<00:00,  5.90s/it]
# step 9 of 10
#   0%|          | 0/11 [00:00<?, ?it/s]
# timeout occurred in solve_ivp_with_timeout
#   9%|▉         | 1/11 [00:06<01:00,  6.03s/it]
# timeout occurred in solve_ivp_with_timeout
#  18%|█▊        | 2/11 [00:12<00:54,  6.08s/it]
# timeout occurred in solve_ivp_with_timeout
#  27%|██▋       | 3/11 [00:18<00:48,  6.03s/it]
# timeout occurred in solve_ivp_with_timeout
#  36%|███▋      | 4/11 [00:24<00:42,  6.01s/it]c:\Elliot\docs\education\college\2024-2025\MS project\MS-project\src\SINDyModel.py:9: RuntimeWarning: overflow encountered in power
#   return lambda x: np.prod(np.power(x, power_tuple), axis=1)
# c:\Elliot\docs\education\college\2024-2025\MS project\MS-project\src\SINDyModel.py:131: RuntimeWarning: invalid value encountered in matmul
#   x_dot = Theta @ self.Xi
# c:\Users\Elliot\anaconda3\envs\ds312\Lib\site-packages\scipy\integrate\_ivp\lsoda.py:161: UserWarning: lsoda: Excess accuracy requested (tolerances too small).
#   solver._y, solver.t = integrator.run(
#  45%|████▌     | 5/11 [00:29<00:35,  5.95s/it]
# timeout occurred in solve_ivp_with_timeout
#  55%|█████▍    | 6/11 [00:35<00:29,  5.93s/it]
# timeout occurred in solve_ivp_with_timeout
#  64%|██████▎   | 7/11 [00:41<00:23,  5.93s/it]
# timeout occurred in solve_ivp_with_timeout
#  82%|████████▏ | 9/11 [00:53<00:11,  5.80s/it]
# timeout occurred in solve_ivp_with_timeout
# 100%|██████████| 11/11 [01:01<00:00,  5.61s/it]
# step 10 of 10
#   9%|▉         | 1/11 [00:01<00:14,  1.48s/it]
# timeout occurred in solve_ivp_with_timeout
#  18%|█▊        | 2/11 [00:07<00:36,  4.03s/it]c:\Users\Elliot\anaconda3\envs\ds312\Lib\site-packages\scipy\integrate\_ivp\lsoda.py:161: UserWarning: lsoda: Repeated error test failures (internal error).
#   solver._y, solver.t = integrator.run(
#  27%|██▋       | 3/11 [00:13<00:38,  4.81s/it]c:\Users\Elliot\anaconda3\envs\ds312\Lib\site-packages\numpy\core\fromnumeric.py:88: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#  36%|███▋      | 4/11 [00:18<00:35,  5.10s/it]
# timeout occurred in solve_ivp_with_timeout
#  55%|█████▍    | 6/11 [00:30<00:27,  5.57s/it]
# timeout occurred in solve_ivp_with_timeout
#  73%|███████▎  | 8/11 [00:40<00:16,  5.34s/it]
# timeout occurred in solve_ivp_with_timeout
# 100%|██████████| 11/11 [00:52<00:00,  4.81s/it]
# ******************************Lorenz System******************************
# rows are noise_level. there are 10 rows.
# columns are threshold. there are 11 columns.
