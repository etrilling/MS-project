# %%
import numpy as np
import matplotlib.pyplot as plt

corr = 0.90
coeff = np.array([[1, corr], [corr, 1]])

np.random.seed(0)
random_sample = np.random.multivariate_normal([0, 0], coeff, 1000)

plt.scatter(random_sample[:, 0], random_sample[:, 1])
plt.xlim(-3, 3)
plt.ylim(-3, 3)
# Out:
# (-3.0, 3.0)
