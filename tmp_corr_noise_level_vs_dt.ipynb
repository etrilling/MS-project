# %%
# %load_ext autoreload
# %autoreload 2

from src.dynamical_systems import *
from src.SINDyModel import *
from src.derivatives import *
from src.helpers import *
from src.experiments import *

import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
dts = np.logspace(-2, 0, 11).tolist()
noise_levels = np.logspace(-3, 0, 10).tolist()

test_suite_config = {
    'lotka_volterra': {
        't_eval_test': np.arange(0, 50 + 0.01, 0.01),
        'noise_level': noise_levels,
        'dt_train': dts,
        't_span_train': (0, 50)
    },

    'van_der_pol_oscillator': {
        't_eval_test': np.arange(0, 25 + 0.01, 0.01),
        'noise_level': noise_levels,
        'dt_train': dts,
        't_span_train': (0, 25)
    },

    'duffing_oscillator': {
        't_eval_test': np.arange(0, 50 + 0.01, 0.01),
        'noise_level': noise_levels,
        'dt_train': dts,
        't_span_train': (0, 50)
    },

    'nonlinear_pendulum': {
        't_eval_test': np.arange(0, 25 + 0.01, 0.01),
        'noise_level': noise_levels,
        'dt_train': dts,
        't_span_train': (0, 25)
    },

    'lorenz': {
        't_eval_test': np.arange(0, 10 + 0.01, 0.01),
        'noise_level': noise_levels,
        'dt_train': np.logspace(-3, 0, 12).tolist(),
        't_span_train': (0, 10)
    },
}

list_of_results, list_of_experiment_configs = run_test_suite(test_suite_config, use_ESINDy=True, generate_prediction=False)
# Out:
# ******************************lotka_volterra******************************
# rows are noise_level. there are 10 rows.
# columns are dt_train. there are 11 columns.
# step 1 of 10
# 100%|██████████| 11/11 [00:04<00:00,  2.23it/s]
# step 2 of 10
# 100%|██████████| 11/11 [00:07<00:00,  1.42it/s]
# step 3 of 10
# 100%|██████████| 11/11 [00:08<00:00,  1.29it/s]
# step 4 of 10
# 100%|██████████| 11/11 [00:08<00:00,  1.26it/s]
# step 5 of 10
# 100%|██████████| 11/11 [00:09<00:00,  1.15it/s]
# step 6 of 10
# 100%|██████████| 11/11 [00:09<00:00,  1.19it/s]
# step 7 of 10
# 100%|██████████| 11/11 [00:09<00:00,  1.20it/s]
# step 8 of 10
# 100%|██████████| 11/11 [00:09<00:00,  1.13it/s]
# step 9 of 10
# 100%|██████████| 11/11 [00:06<00:00,  1.62it/s]
# step 10 of 10
# 100%|██████████| 11/11 [00:04<00:00,  2.30it/s]
# rows are noise_level. there are 10 rows.
# columns are dt_train. there are 11 columns.
# ******************************van_der_pol_oscillator******************************
# rows are noise_level. there are 10 rows.
# columns are dt_train. there are 11 columns.
# step 1 of 10
# 100%|██████████| 11/11 [00:03<00:00,  3.27it/s]
# step 2 of 10
# 100%|██████████| 11/11 [00:03<00:00,  3.22it/s]
# step 3 of 10
# 100%|██████████| 11/11 [00:03<00:00,  3.23it/s]
# step 4 of 10
# 100%|██████████| 11/11 [00:03<00:00,  2.97it/s]
# step 5 of 10
# 100%|██████████| 11/11 [00:03<00:00,  2.78it/s]
# step 6 of 10
# 100%|██████████| 11/11 [00:04<00:00,  2.53it/s]
# step 7 of 10
# 100%|██████████| 11/11 [00:04<00:00,  2.25it/s]
# step 8 of 10
# 100%|██████████| 11/11 [00:04<00:00,  2.35it/s]
# step 9 of 10
# 100%|██████████| 11/11 [00:04<00:00,  2.41it/s]
# step 10 of 10
# 100%|██████████| 11/11 [00:04<00:00,  2.57it/s]
# rows are noise_level. there are 10 rows.
# columns are dt_train. there are 11 columns.
# ******************************duffing_oscillator******************************
# rows are noise_level. there are 10 rows.
# columns are dt_train. there are 11 columns.
# step 1 of 10
# 100%|██████████| 11/11 [00:05<00:00,  2.08it/s]
# step 2 of 10
# 100%|██████████| 11/11 [00:05<00:00,  1.89it/s]
# step 3 of 10
# 100%|██████████| 11/11 [00:07<00:00,  1.52it/s]
# step 4 of 10
# 100%|██████████| 11/11 [00:07<00:00,  1.39it/s]
# step 5 of 10
# 100%|██████████| 11/11 [00:06<00:00,  1.69it/s]
# step 6 of 10
# 100%|██████████| 11/11 [00:06<00:00,  1.77it/s]
# step 7 of 10
# 100%|██████████| 11/11 [00:06<00:00,  1.82it/s]
# step 8 of 10
# 100%|██████████| 11/11 [00:05<00:00,  1.87it/s]
# step 9 of 10
# 100%|██████████| 11/11 [00:05<00:00,  1.99it/s]
# step 10 of 10
# 100%|██████████| 11/11 [00:05<00:00,  2.13it/s]
# rows are noise_level. there are 10 rows.
# columns are dt_train. there are 11 columns.
# ******************************nonlinear_pendulum******************************
# rows are noise_level. there are 10 rows.
# columns are dt_train. there are 11 columns.
# step 1 of 10
# 100%|██████████| 11/11 [00:01<00:00,  6.78it/s]
# step 2 of 10
# 100%|██████████| 11/11 [00:01<00:00,  6.09it/s]
# step 3 of 10
# 100%|██████████| 11/11 [00:01<00:00,  5.58it/s]
# step 4 of 10
# 100%|██████████| 11/11 [00:02<00:00,  4.10it/s]
# step 5 of 10
# 100%|██████████| 11/11 [00:02<00:00,  3.70it/s]
# step 6 of 10
# 100%|██████████| 11/11 [00:02<00:00,  4.80it/s]
# step 7 of 10
# 100%|██████████| 11/11 [00:02<00:00,  4.77it/s]
# step 8 of 10
# 100%|██████████| 11/11 [00:01<00:00,  5.51it/s]
# step 9 of 10
# 100%|██████████| 11/11 [00:01<00:00,  5.98it/s]
# step 10 of 10
# 100%|██████████| 11/11 [00:01<00:00,  5.99it/s]
# rows are noise_level. there are 10 rows.
# columns are dt_train. there are 11 columns.
# ******************************lorenz******************************
# rows are noise_level. there are 10 rows.
# columns are dt_train. there are 12 columns.
# step 1 of 10
# 100%|██████████| 12/12 [00:28<00:00,  2.38s/it]
# step 2 of 10
# 100%|██████████| 12/12 [00:28<00:00,  2.37s/it]
# step 3 of 10
# 100%|██████████| 12/12 [00:24<00:00,  2.00s/it]
# step 4 of 10
# 100%|██████████| 12/12 [00:24<00:00,  2.02s/it]
# step 5 of 10
# 100%|██████████| 12/12 [00:25<00:00,  2.10s/it]
# step 6 of 10
# 100%|██████████| 12/12 [00:25<00:00,  2.11s/it]
# step 7 of 10
# 100%|██████████| 12/12 [00:28<00:00,  2.35s/it]
# step 8 of 10
# 100%|██████████| 12/12 [00:27<00:00,  2.27s/it]
# step 9 of 10
# 100%|██████████| 12/12 [00:24<00:00,  2.05s/it]
# step 10 of 10
# 100%|██████████| 12/12 [00:22<00:00,  1.85s/it]
# rows are noise_level. there are 10 rows.
# columns are dt_train. there are 12 columns.

# %%
def find_correct_system_points(experiment_config, results):
    list1_name, list1, list2_name, list2 = extract_list_items(experiment_config)
    
    # extract the true coefficients from the experiment configuration
    true_coeffs = experiment_config['true_coeffs']

    correct_system_pts = []
    for i in range(len(list1)):
        for j in range(len(list2)):
            model_xi = results[i][j]["model_xi"]

            # if the predicted model has the same non-zero coefficients as the true model, add this point
            if np.array_equal(np.nonzero(model_xi), np.nonzero(true_coeffs)):
                correct_system_pts.append([list1[i], list2[j]])
    
    return correct_system_pts    


# def calculate_correlation(experiment_config, results):
#     pts = find_correct_system_points(experiment_config, results)

#     pts = [(noise_level, end - start) for noise_level, (start, end) in pts]

#     pts = np.array(pts)
#     pts_x = pts[:, 1]
#     pts_y = pts[:, 0]

#     return np.corrcoef(pts_x, pts_y)[0, 1]


for system_name, experiment_config, results in zip(test_suite_config.keys(), list_of_experiment_configs, list_of_results):
    # cor = calculate_correlation(experiment_config, results)

    pts = find_correct_system_points(experiment_config, results)

    pts = [(noise_level, dt) for noise_level, dt in pts]

    if len(pts) == 0:
        continue

    pts = np.array(pts)
    pts_x = pts[:, 1]
    pts_y = pts[:, 0]

    a, b = np.polyfit(pts_x, pts_y, 1)
    cor = np.corrcoef(pts_x, pts_y)[0, 1]
    print(f'Correlation for {system_name} is {cor}, slope is {a}')

    plt.plot(pts_x, pts_y, 'o')
    plt.plot(pts_x, a * pts_x + b)
    # plt.gca().invert_xaxis()
    plt.show()
# Out:
# Correlation for lotka_volterra is -0.2059129748005514, slope is -0.024250204898640035
# Correlation for van_der_pol_oscillator is 0.20592882189626274, slope is 0.07528341980142572
# Correlation for duffing_oscillator is 0.322972262767116, slope is 0.007545207176058879
# Correlation for lorenz is 0.05087233735675484, slope is 0.010258735031324092
