# %%
# %load_ext autoreload
# %autoreload 2

from src.dynamical_systems import *
from src.SINDyModel import *
from src.derivatives import *
from src.helpers import *
from src.experiments import *

import matplotlib.pyplot as plt
from tqdm import tqdm

# %% [markdown]
# # Lotka-Volterra

# %%
lotka_volterra_rhs = generate_lotka_volterra_rhs(1, 0.1, 1.5, 0.75)
true_coeffs = generate_lotka_volterra_true_coefficients(1, 0.1, 1.5, 0.75)


noise_levels = np.logspace(-3, 0, 10).tolist()
thresholds = np.logspace(-3, -0.5, 11).tolist()

t_span = (0, 20)

# if a parameter is a list, the experiment will be run for each combination of the parameters
# if a parameter is not a list, the same value will be used for all experiments
# the first list will be the rows and the second list will be the columns
experiment_config = {
    # define fixed parameters
    'rhs': lotka_volterra_rhs,
    'derivative_approximation': dxdt_finite_difference,
    't_eval_test': np.arange(t_span[0], t_span[1] + 0.01, 0.01),
    'np_seed': 0,
    # define parameters that can be lists
    'x0': (10, 5),
    'noise_level': noise_levels,
    't_eval_train': None, 'dt_train': 0.1, 't_span_train': (0, 13),
    'train_interpolation_dt': 0.01,
    'threshold': thresholds,
    'poly_order': 5,
    'n_frequencies': 0,
    # define parameters that are used after the experiment
    'true_coeffs': true_coeffs
}

results = run_experiment(experiment_config)
# Out:
# rows are noise_level. there are 10 rows.
# columns are threshold. there are 11 columns.
# step 1 of 10
#   9%|▉         | 1/11 [00:00<00:03,  3.12it/s]c:\Elliot\docs\education\college\2024-2025\MS project\MS-project\src\SINDyModel.py:9: RuntimeWarning: overflow encountered in power
#   return lambda x: np.prod(np.power(x, power_tuple), axis=1)
# c:\Elliot\docs\education\college\2024-2025\MS project\MS-project\src\SINDyModel.py:142: RuntimeWarning: invalid value encountered in matmul
#   x_dot = Theta @ self.Xi
# c:\Users\Elliot\anaconda3\envs\ds312\Lib\site-packages\scipy\integrate\_ivp\lsoda.py:161: UserWarning: lsoda: Excess accuracy requested (tolerances too small).
#   solver._y, solver.t = integrator.run(
# 100%|██████████| 11/11 [00:05<00:00,  2.04it/s]
# step 2 of 10
# 100%|██████████| 11/11 [00:04<00:00,  2.43it/s]
# step 3 of 10
# 100%|██████████| 11/11 [00:08<00:00,  1.30it/s]
# step 4 of 10
# 100%|██████████| 11/11 [00:10<00:00,  1.04it/s]
# step 5 of 10
# 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# step 6 of 10
# 100%|██████████| 11/11 [00:13<00:00,  1.22s/it]
# step 7 of 10
# 100%|██████████| 11/11 [00:10<00:00,  1.08it/s]
# step 8 of 10
# 100%|██████████| 11/11 [00:07<00:00,  1.40it/s]
# step 9 of 10
# 100%|██████████| 11/11 [00:09<00:00,  1.19it/s]
# step 10 of 10
# 100%|██████████| 11/11 [00:06<00:00,  1.76it/s]

# %%
plot_heatmaps(experiment_config, results)
# Out:
# rows are noise_level. there are 10 rows.
# columns are threshold. there are 11 columns.

# %%
display_single_result(experiment_config, results, 7, 0, keys_to_display=['x_test', 'x_pred', 'x_train_noisy'])
# Out:
# x0' = + 0.99044 x0 + -0.09836 x0 x1
# x1' = + -1.49048 x1 + 0.73781 x0 x1

# %% [markdown]
# # Duffing Oscillator

# %%
duffing_oscillator_rhs = generate_duffing_oscillator_rhs(0.2, 0.2, 0.1)
true_coeffs = generate_duffing_oscillator_true_coefficients(0.2, 0.2, 0.1)


noise_levels = np.logspace(-3, 0, 10).tolist()
thresholds = np.logspace(-3, -0.5, 11).tolist()

t_span = (0, 15)

# if a parameter is a list, the experiment will be run for each combination of the parameters
# if a parameter is not a list, the same value will be used for all experiments
# the first list will be the rows and the second list will be the columns
experiment_config2 = {
    # define fixed parameters
    'rhs': duffing_oscillator_rhs,
    'derivative_approximation': dxdt_finite_difference,
    # 'derivative_approximation': lambda x, t: dxdt_poly_fit(x, t, 3, 3),
    't_eval_test': np.arange(t_span[0], t_span[1] + 0.01, 0.01),
    'np_seed': 0,
    # define parameters that can be lists
    'x0': (10, 5),
    'noise_level': noise_levels,
    't_eval_train': None, 'dt_train': 0.2, 't_span_train': (0, 5),
    'train_interpolation_dt': 0.01,
    'threshold': thresholds,
    'poly_order': 5,
    'n_frequencies': 0,
    # define parameters that are used after the experiment
    'true_coeffs': true_coeffs
}

results2 = run_experiment(experiment_config2)
# Out:
# rows are noise_level. there are 10 rows.
# columns are threshold. there are 11 columns.
# step 1 of 10
# 100%|██████████| 11/11 [00:04<00:00,  2.72it/s]
# step 2 of 10
# 100%|██████████| 11/11 [00:04<00:00,  2.34it/s]
# step 3 of 10
# 100%|██████████| 11/11 [00:04<00:00,  2.42it/s]
# step 4 of 10
# 100%|██████████| 11/11 [00:04<00:00,  2.57it/s]
# step 5 of 10
# 100%|██████████| 11/11 [00:04<00:00,  2.54it/s]
# step 6 of 10
# 100%|██████████| 11/11 [00:04<00:00,  2.58it/s]
# step 7 of 10
# 100%|██████████| 11/11 [00:04<00:00,  2.66it/s]
# step 8 of 10
# 100%|██████████| 11/11 [00:04<00:00,  2.68it/s]
# step 9 of 10
# 100%|██████████| 11/11 [00:03<00:00,  3.55it/s]
# step 10 of 10
# 100%|██████████| 11/11 [00:02<00:00,  3.70it/s]

# %%
plot_heatmaps(experiment_config2, results2)
# Out:
# rows are noise_level. there are 10 rows.
# columns are threshold. there are 11 columns.

# %%
display_single_result(experiment_config2, results2, 5, 6, keys_to_display=['x_test', 'x_pred', 'x_train_noisy'])
# Out:
# x0' = + -0.41409 1 + -0.15812 x0 + 1.03096 x1 + -0.02691 x0 x1
# x1' = + -2.87354 1 + -1.30103 x0 + -0.06967 x1 + -0.02227 x0 x1 + 0.02031 x1^2 + -0.07432 x0^3
